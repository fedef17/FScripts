# %%
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt

# %%
sst = xr.load_dataset('/home/fabiano/dump/O_SSTSST_oceanx_01.nc')

# %%
sst = sst.to_array()

# %%
sst = sst.values

# %%
sst.shape
# Out:
# (1, 3, 1, 105704)

# %%
sstok = np.reshape(sst.squeeze(), (3,292,362))

# %%
plt.figure(figsize = (16,9))
plt.imshow(sstok[1], vmin = 270, vmax = 305, cmap='jet')

# %%
plt.hist(sstok[1].flatten(), bins = 100)
plt.ylim((0,5000))
# Out:
# (0.0, 5000.0)

# %%
gigi = xr.open_dataset('/home/fabiano/dump/GLOBONE_atm_6hrs_1979_copy.nc')

# %%
gigi = gigi.rename({'latitude': 'lat', 'longitude': 'lon'})

# %%
import climtools_lib as ctl
# Out:
# libgfortran.so.3: cannot open shared object file: No such file or directory
# No DISPLAY variable set. Switching to agg backend

# %%
# %matplotlib inline

# %%
ctl.plot_multimap_contour(gigi.tas[-250:-1:50], plot_type='pcolormesh', figsize=(16,9))
# Out:
# Adding cyclic point
#
# Adding cyclic point
#
# Adding cyclic point
#
# Adding cyclic point
#
# Adding cyclic point
# [<Figure size 1152x648 with 6 Axes>]

# %%
toa_net = ctl.global_mean(gigi.rlut+gigi.rsnt)

srf_net = ctl.global_mean(gigi.rsns + gigi.rlns + gigi.hfls + gigi.hfss)

# %%
plt.plot(toa_net)

# %%
plt.plot(srf_net)
