# %%
import pickle

# %%
gigi = pickle.load(open('/home/montanarini/output/Task-7/Variables/old/Task-7-hist.p', 'rb'))
gigi2 = pickle.load(open('/home/montanarini/output/Task-7/Variables/prova-hist.p', 'rb'))

# %%
clim, ninoc, ninac = gigi

# %%
from climtools import climtools_lib as ctl
import xarray as xr
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# No DISPLAY variable set. Switching to agg backend

# %%
fig = plt.figure()
clim.plot.contourf(x = 'lon', y ='lev', levels = 17, ylim = (600., 0.))

# %%
ninoc = ninoc.mean('lat')

# %%
iso20 = clim.lev[(clim > 20.).sum(axis = 0)+1]
iso20_nino = clim.lev[(clim+ninoc > 20.).sum(axis = 0)+1]

# %%
plt.figure()
plt.plot(clim.lon, iso20, label = 'clim')
plt.plot(clim.lon, iso20_nino, label = 'nino')
plt.gca().invert_yaxis()
plt.legend()

# %%
def find_t_depth(da, temp = 20.):
    depth = da.lev[(da > temp).sum(axis = 0)+1]
    return depth

# %%
find_t_depth(clim)
# Out:
# <xarray.DataArray 'lev' (lon: 63)>
# array([180.549927, 180.549927, 180.549927, 199.789963, 199.789963, 199.789963,
#        199.789963, 199.789963, 199.789963, 199.789963, 199.789963, 199.789963,
#        199.789963, 199.789963, 199.789963, 199.789963, 199.789963, 199.789963,
#        199.789963, 199.789963, 199.789963, 199.789963, 199.789963, 199.789963,
#        199.789963, 199.789963, 199.789963, 199.789963, 180.549927, 180.549927,
#        180.549927, 180.549927, 180.549927, 180.549927, 163.164459, 163.164459,
#        163.164459, 163.164459, 147.40625 , 147.40625 , 147.40625 , 133.075821,
#        133.075821, 120.      , 120.      , 120.      , 108.030281, 108.030281,
#         97.041313,  97.041313,  86.929428,  77.61116 ,  77.61116 ,  69.021683,
#         69.021683,  61.112839,  61.112839,  61.112839,  53.850636,  53.850636,
#         47.211895,  47.211895,  53.850636])
# Coordinates:
#     lev      (lon) float64 180.5 180.5 180.5 199.8 ... 53.85 47.21 47.21 53.85
# ...

# %%
clim

# %%
fig = plt.figure()
ninoc.plot.contourf(x = 'lon', y ='lev', levels = 17, ylim = (600., 0.))

# %%
gigi2[0].plot.contourf(x = 'lon', y ='lev', levels = 17, ylim = (600., 0.))

# %%
giginu = pickle.load(open('/home/montanarini/output/Task-7/Variables/old/Task-7-b100.p', 'rb'))

# %%
fig = plt.figure()
(giginu[1].mean('lat')-ninoc).plot.contourf(x = 'lon', y ='lev', levels = 17, ylim = (600., 0.))
